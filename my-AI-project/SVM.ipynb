# %% [markdown]
# #SVM分类器对手写体数据分类

# %%
#导入手写体数字加载器
from sklearn.datasets import load_digits
#获取手写体数字数码图像数据并存储在digits变量
digits=load_digits()
#检视数据规模,每张8*8二维图片展平成64维度的向量
digits.data.shape
# Out:
# (1797, 64)

# %%
digits.data
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
#以75%为训练样本，25%为测试样本
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(digits.data,digits.target,test_size=0.25,random_state=33)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1347,)
# (450,)

# %%
from sklearn.preprocessing import StandardScaler
#导入基于线性假设的支持向量机分类器LinearSVC
from sklearn.svm import LinearSVC
#数据标准化
ss=StandardScaler()
x_train=ss.fit_transform(x_train)
x_test=ss.transform(x_test)

#初始化线性假设的支持向量机
lsvc=LinearSVC()
#模型训练
lsvc.fit(x_train,y_train)
y_predict=lsvc.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
y_predict
# Out:
# array([1, 3, 7, 3, 2, 4, 6, 1, 4, 0, 4, 7, 9, 5, 2, 8, 3, 6, 7, 0, 6, 0,
#        8, 3, 0, 6, 2, 3, 0, 9, 0, 2, 0, 6, 9, 1, 1, 5, 8, 0, 6, 1, 5, 8,
#        9, 5, 1, 6, 2, 6, 6, 7, 6, 7, 7, 2, 7, 8, 0, 7, 3, 6, 3, 9, 6, 6,
#        5, 5, 4, 2, 9, 3, 7, 6, 5, 7, 2, 8, 1, 2, 2, 8, 1, 1, 6, 3, 5, 0,
#        0, 1, 6, 7, 6, 8, 9, 7, 0, 0, 9, 8, 0, 8, 2, 3, 6, 1, 9, 9, 1, 7,
#        3, 9, 8, 8, 5, 9, 5, 1, 1, 7, 9, 3, 3, 2, 8, 1, 3, 8, 6, 4, 0, 0,
#        0, 7, 1, 5, 5, 1, 8, 5, 1, 8, 1, 6, 9, 9, 4, 5, 7, 5, 2, 1, 2, 5,
#        8, 7, 7, 5, 1, 9, 6, 9, 8, 0, 6, 1, 2, 1, 5, 7, 8, 9, 6, 8, 4, 1,
#        0, 0, 9, 8, 7, 2, 8, 6, 4, 8, 9, 4, 2, 6, 1, 8, 5, 6, 7, 5, 1, 9,
#        2, 8, 3, 2, 9, 4, 3, 5, 5, 6, 2, 4, 3, 2, 6, 4, 8, 5, 8, 0, 8, 8,
#        6, 3, 2, 3, 0, 5, 7, 1, 3, 9, 3, 2, 1, 6, 6, 5, 1, 9, 7, 2, 4, 5,
#        2, 1, 3, 1, 1, 2, 1, 7, 0, 1, 2, 2, 1, 2, 4, 9, 6, 6, 3, 9, 2, 8,
#        1, 5, 5, 1, 8, 6, 2, 5, 6, 0, 1, 4, 2, 1, 8, 9, 4, 3, 0, 6, 8, 3,
#        3, 2, 0, 2, 0, 6, 5, 6, 6, 4, 6, 1, 8, 3, 4, 1, 3, 5, 1, 4, 9, 8,
#        7, 5, 1, 1, 3, 7, 8, 8, 3, 7, 4, 0, 7, 2, 8, 7, 1, 9, 4, 5, 3, 5,
#        2, 5, 1, 3, 0, 5, 8, 4, 7, 6, 9, 9, 3, 3, 4, 0, 6, 4, 7, 0, 6, 1,
#        2, 3, 3, 4, 5, 3, 3, 5, 2, 0, 9, 7, 1, 5, 5, 8, 4, 4, 3, 6, 2, 5,
#        1, 0, 6, 1, 5, 8, 4, 7, 6, 4, 3, 4, 0, 3, 0, 1, 2, 8, 0, 5, 4, 5,
#        2, 2, 9, 6, 9, 8, 0, 8, 8, 2, 4, 6, 5, 6, 4, 3, 9, 8, 9, 7, 1, 7,
#        9, 4, 1, 9, 9, 5, 9, 8, 0, 8, 2, 5, 1, 4, 2, 6, 3, 7, 9, 3, 7, 4,
#        3, 7, 1, 8, 8, 9, 5, 3, 6, 6])

# %%
#模型评估
print(f"Acc of LinearSVC:{lsvc.score(x_test,y_test)}")
from sklearn.metrics import classification_report
print(classification_report(y_test,y_predict,target_names=digits.target_names.astype(str)))
# Out:
# Acc of LinearSVC:0.9533333333333334
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        35
#            1       0.96      0.98      0.97        54
#            2       0.98      1.00      0.99        44
#            3       0.93      0.93      0.93        46
#            4       0.97      1.00      0.99        35
#            5       0.94      0.94      0.94        48
#            6       0.96      0.98      0.97        51
#            7       0.92      1.00      0.96        35
#            8       0.98      0.84      0.91        58
#            9       0.95      0.91      0.93        44
#
#     accuracy                           0.95       450
#    macro avg       0.95      0.96      0.95       450
# weighted avg       0.95      0.95      0.95       450

# %% [markdown]
# SVM的优点包括：
#
# 在高维空间中表现良好，适用于处理高维数据。
# 可以通过选择不同的核函数来适应不同类型的数据。
# 在样本量较小时仍然有效，对于维度较高的数据也适用。
#
# SVM的缺点包括：
#
# 训练时间较长，特别是对于大规模数据集。
# 对缺失数据敏感，需要对数据进行处理。
